# %% [markdown]
# Exercise 14
# Go to this page https://www.w3schools.com/sql/trysql.asp?filename=trysql_select_all
# 1. Which SQL keyword is used to combine multiple conditions in a WHERE clause?
# 2. Which SQL function counts the number of rows in a table?
# 3. Which SQL keyword ensures only unique values are returned in a query?
# 4. Which SQL clause is used to sort results?
# 5. Which SQL function returns the maximum value from a column?

# %% [markdown]
# 1. AND
# 2. COUNT() / COUNT
# 3. SELECT DISTINCT / DISTINCT
# 4. ORDER BY
# 5. MAX()
#
# answer - acsom / ASCOM
